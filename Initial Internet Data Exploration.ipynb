# %%
import pandas as pd

# %%
df = pd.read_csv('country_daily_speeds.csv')

df.head()
# Out:
#          country country_code        date  download_kbps  upload_kbps  \
# 0  United States           US  2008-01-01        5962.06      925.211
# 1  United States           US  2008-01-02        6002.74      927.547
# 2  United States           US  2008-01-03        6040.98      929.717
# 3  United States           US  2008-01-04        6031.44      929.833
# 4  United States           US  2008-01-05        6029.91      927.522
#
#    total_tests  distance_miles
# 0      1666258         127.944
# 1      1673994         128.022
# 2      1680703         127.997
# 3      1686670         127.961
# 4      1691219         127.742

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                   country country_code        date  \
# 0                           United States           US  2008-01-01
# 1                           United States           US  2008-01-02
# 2                           United States           US  2008-01-03
# 3                           United States           US  2008-01-04
# 4                           United States           US  2008-01-05
# ...                                   ...          ...         ...
# 406973  Bonaire, Saint Eustatius and Saba           BQ  2014-09-26
# 406974  Bonaire, Saint Eustatius and Saba           BQ  2014-09-29
# 406975  Bonaire, Saint Eustatius and Saba           BQ  2014-09-30
# 406976  Bonaire, Saint Eustatius and Saba           BQ  2014-10-01
# 406977  Bonaire, Saint Eustatius and Saba           BQ  2014-10-02
#
#         download_kbps  upload_kbps  total_tests  distance_miles
# 0             5962.06      925.211      1666258        127.9440
# ...

# %%
df.dtypes
# Out:
# country            object
# country_code       object
# date               object
# download_kbps     float64
# upload_kbps       float64
# total_tests         int64
# distance_miles    float64
# dtype: object

# %%
df['date'].value_counts()
# Out:
# 2014-08-29    194
# 2014-08-15    194
# 2014-08-27    194
# 2014-08-12    194
# 2014-10-02    194
#              ...
# 2008-01-06    112
# 2008-01-11    112
# 2008-01-05    111
# 2008-01-04    110
# 2008-01-01    110
# Name: date, Length: 2467, dtype: int64

# %%
df
# Out:
#                                   country country_code        date  \
# 0                           United States           US  2008-01-01
# 1                           United States           US  2008-01-02
# 2                           United States           US  2008-01-03
# 3                           United States           US  2008-01-04
# 4                           United States           US  2008-01-05
# ...                                   ...          ...         ...
# 406973  Bonaire, Saint Eustatius and Saba           BQ  2014-09-26
# 406974  Bonaire, Saint Eustatius and Saba           BQ  2014-09-29
# 406975  Bonaire, Saint Eustatius and Saba           BQ  2014-09-30
# 406976  Bonaire, Saint Eustatius and Saba           BQ  2014-10-01
# 406977  Bonaire, Saint Eustatius and Saba           BQ  2014-10-02
#
#         download_kbps  upload_kbps  total_tests  distance_miles
# 0             5962.06      925.211      1666258        127.9440
# ...

# %% [markdown]
# - df['a'].plot()
# - plt.title('My Graph')
# - plt.xlabel('x axis')
# - plt.ylabel('y axis')
# - df['b'].plot()
# - plt.show()

# %%
# df.loc[df['column_name'] == some_value]
test = df.loc[df['country_code'] == 'US']

# %%
test
# Out:
#             country country_code        date  download_kbps  upload_kbps  \
# 0     United States           US  2008-01-01        5962.06      925.211
# 1     United States           US  2008-01-02        6002.74      927.547
# 2     United States           US  2008-01-03        6040.98      929.717
# 3     United States           US  2008-01-04        6031.44      929.833
# 4     United States           US  2008-01-05        6029.91      927.522
# ...             ...          ...         ...            ...          ...
# 2462  United States           US  2014-09-28       29833.30     9198.150
# 2463  United States           US  2014-09-29       29828.80     9229.120
# 2464  United States           US  2014-09-30       29867.80     9258.580
# 2465  United States           US  2014-10-01       29921.70     9292.520
# 2466  United States           US  2014-10-02       29957.50     9305.520
#
#       total_tests  distance_miles
# 0         1666258        127.9440
# ...

# %%
import matplotlib 

test['download_kbps'].plot()

plt
# Out:
# <module 'matplotlib' from '/Users/jeremyspradlin/.local/share/virtualenvs/InternetData-7vU38RpI/lib/python3.8/site-packages/matplotlib/__init__.py'>

# %%
test['total_tests'].plot()
# Out:
# <AxesSubplot:>
